# %%
#This is the analysis of TVF romantic video where the entire story was setup with a song being played in the background
import pandas as pd 
anew=pd.read_csv(r"D:\video_comments2.csv") 
anew
# Out:
#                                               comments
# 0    Our relationship status is Na Tum Jano Na Hum ...
# 1                              Hrudayat Vaje Something
# 2    I tried finding the hoodie on Meesho but I did...
# 3                                            Love it ❤
# 4                          So amazing video 😍❤❤❤❤❤❤❤❤❤
# ..                                                 ...
# 631         ❤❤❤ aise he single logoki jalate rahiye 🔥🔥
# 632                                   Where is apoorva
# 633                                         AYUSH BACK
# 634               Whoaa AYUSH AND BARKHA IS NOT BACK❤😔
# 635                                       IM EXCITEDDD
#
# [636 rows x 1 columns]

# %%
#Lowe casing 
anew['comments']=anew['comments'].str.lower() 
anew
# Out:
#                                               comments
# 0    our relationship status is na tum jano na hum ...
# 1                              hrudayat vaje something
# 2    i tried finding the hoodie on meesho but i did...
# 3                                            love it ❤
# 4                          so amazing video 😍❤❤❤❤❤❤❤❤❤
# ..                                                 ...
# 631         ❤❤❤ aise he single logoki jalate rahiye 🔥🔥
# 632                                   where is apoorva
# 633                                         ayush back
# 634               whoaa ayush and barkha is not back❤😔
# 635                                       im exciteddd
#
# [636 rows x 1 columns]

# %%
#removing leading and trailing spaces 
anew['comments']=anew['comments'].str.strip() 
anew
# Out:
#                                               comments
# 0    our relationship status is na tum jano na hum ...
# 1                              hrudayat vaje something
# 2    i tried finding the hoodie on meesho but i did...
# 3                                            love it ❤
# 4                          so amazing video 😍❤❤❤❤❤❤❤❤❤
# ..                                                 ...
# 631         ❤❤❤ aise he single logoki jalate rahiye 🔥🔥
# 632                                   where is apoorva
# 633                                         ayush back
# 634               whoaa ayush and barkha is not back❤😔
# 635                                       im exciteddd
#
# [636 rows x 1 columns]

# %%
#finding html tags 
anew[anew['comments'].str.contains(r"<.*?>")]
# Out:
#                                               comments
# 0    our relationship status is na tum jano na hum ...
# 12   actually barkha n aisha were in this video too...
# 30   <a href="http://www.youtube.com/results?search...
# 42   ya i was waiting for the masterpiece<br>let&#3...
# 48   baby u know that&#39;s not how it works <br><b...
# 55   loved it too much 😭💕 <br>this video was so swe...
# 58   really loved it.. <br>ayush&#39;s one of the b...
# 62   i completed 4th time watching it.<br>wish to w...
# 74   stay strong kings👑. <br>the world still needs us💪
# 98   loved the way you shoot the video❤️<br>beautif...
# 137  nayana is backkkk 😍<br>loved a filtercopy vide...
# 140                 for men : <br>weak up to reality 🥲
# 143  here again &amp; again <br>just to enjoy this ...
# 164  this song along with the vid made it a filterc...
# 170  giggled and blush soooooo hard because of ayus...
# 178  yaar you guys should have made him say :<br>le...
# ...

# %%
#removing html tags 
anew['comments']=anew['comments'].str.replace(r"<.*?>",'')
anew[anew['comments'].str.contains(r"<.*?>")]
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22320\1520031179.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   anew['comments']=anew['comments'].str.replace(r"<.*?>",'')
# Empty DataFrame
# Columns: [comments]
# Index: []

# %%
#checking if URL exists or not 
anew[anew['comments'].str.contains(r"https?://\S+|www\.\S+")]
# Out:
#                                               comments
# 0    our relationship status is na tum jano na hum ...
# 592  our relationship status is na tum jano na hum ...

# %%
#remove URLS 
anew['comments']=anew['comments'].str.replace(r"https?://\S+|www\.\S+","") 
anew[anew['comments'].str.contains(r"https?://\S+|www\.\S+")]
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22320\2592410744.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   anew['comments']=anew['comments'].str.replace(r"https?://\S+|www\.\S+","")
# Empty DataFrame
# Columns: [comments]
# Index: []

# %%
def remove_abb(data):
    data = re.sub(r"he's", "he is", data)
    data = re.sub(r"there's", "there is", data)
    data = re.sub(r"we're", "we are", data)
    data = re.sub(r"that's", "that is", data)
    data = re.sub(r"won't", "will not", data)
    data = re.sub(r"they're", "they are", data)
    data = re.sub(r"can't", "cannot", data)
    data = re.sub(r"wasn't", "was not", data)
    data = re.sub(r"don't", "do not", data)
    data= re.sub(r"aren't", "are not", data)
    data = re.sub(r"isn't", "is not", data)
    data = re.sub(r"what's", "what is", data)
    data = re.sub(r"haven't", "have not", data)
    data = re.sub(r"hasn't", "has not", data)
    data = re.sub(r"there's", "there is", data)
    data = re.sub(r"he's", "he is", data)
    data = re.sub(r"it's", "it is", data)
    data = re.sub(r"you're", "you are", data)
    data = re.sub(r"i'm", "i am", data)
    data = re.sub(r"shouldn't", "should not", data)
    data = re.sub(r"wouldn't", "would not", data)
    data = re.sub(r"i'm", "i am", data)
    data = re.sub(r"i'm", "i am", data)
    data = re.sub(r"i'm", "i am", data)
    data = re.sub(r"isn't", "is not", data)
    data = re.sub(r"here's", "here is", data)
    data = re.sub(r"you've", "you have", data)
    data = re.sub(r"you've", "you have", data)
    data = re.sub(r"we're", "we are", data)
    data = re.sub(r"what's", "what is", data)
    data = re.sub(r"couldn't", "could not", data)
    data = re.sub(r"we've", "we have", data)
    data = re.sub(r"it's", "it is", data)
    data = re.sub(r"doesn't", "does not", data)
    data = re.sub(r"it's", "it is", data)
    data = re.sub(r"here's", "here is", data)
    data = re.sub(r"who's", "who is", data)
    data = re.sub(r"i've", "i have", data)
    data = re.sub(r"y'all", "you all", data)
    data = re.sub(r"can't", "cannot", data)
    data = re.sub(r"would've", "would have", data)
    data = re.sub(r"it'll", "it will", data)
    data = re.sub(r"we'll", "we will", data)
    data = re.sub(r"wouldn't", "would not", data)
    data = re.sub(r"we've", "we have", data)
    data = re.sub(r"he'll", "he will", data)
    data = re.sub(r"y'all", "you all", data)
    data = re.sub(r"weren't", "were not", data)
    data = re.sub(r"didn't", "did not", data)
    data = re.sub(r"they'll", "they will", data)
    data = re.sub(r"they'd", "they would", data)
    data = re.sub(r"don't", "do not", data)
    data = re.sub(r"that's", "that is", data)
    data = re.sub(r"they've", "they have", data)
    data = re.sub(r"i'd", "i would", data)
    data = re.sub(r"should've", "should have", data)
    data = re.sub(r"you're", "you are", data)
    data = re.sub(r"where's", "where is", data)
    data = re.sub(r"don't", "do not", data)
    data = re.sub(r"we'd", "we would", data)
    data = re.sub(r"i'll", "I will", data)
    data = re.sub(r"weren't", "were not", data)
    data = re.sub(r"they're", "they are", data)
    data = re.sub(r"can't", "cannot", data)
    data = re.sub(r"you'll", "you will", data)
    data = re.sub(r"i'd", "i would", data)
    data = re.sub(r"let's", "let us", data)
    data = re.sub(r"it's", "it is", data)
    data = re.sub(r"can't", "cannot", data)
    data = re.sub(r"don't", "do not", data)
    data = re.sub(r"you're", "you are", data)
    data = re.sub(r"i've", "i have", data)
    data = re.sub(r"that's", "that is", data)
    data = re.sub(r"i'll", "i will", data)
    data = re.sub(r"doesn't", "does not",data)
    data = re.sub(r"i'd", "i would", data)
    data = re.sub(r"didn't", "did not", data)
    data = re.sub(r"ain't", "am not", data)
    data = re.sub(r"you'll", "you will", data)
    data = re.sub(r"i've", "i have", data)
    data = re.sub(r"don't", "do not", data)
    data = re.sub(r"i'll", "i will", data)
    data = re.sub(r"i'd", "i would", data)
    data = re.sub(r"let's", "let us", data)
    data = re.sub(r"you'd", "you would", data)
    data = re.sub(r"it's", "it is", data)
    data = re.sub(r"ain't", "am not", data)
    data = re.sub(r"haven't", "have not", data)
    data = re.sub(r"could've", "could have", data)
    data = re.sub(r"youve", "you have", data)  
    data = re.sub(r"don't", "do not", data)
    
    return data

# %%
#abbreviations are expanded
import re 
anew['comments']=anew['comments'].apply(remove_abb)
anew
# Out:
#                                               comments
# 0    our relationship status is na tum jano na hum ...
# 1                              hrudayat vaje something
# 2    i tried finding the hoodie on meesho but i did...
# 3                                            love it ❤
# 4                          so amazing video 😍❤❤❤❤❤❤❤❤❤
# ..                                                 ...
# 631         ❤❤❤ aise he single logoki jalate rahiye 🔥🔥
# 632                                   where is apoorva
# 633                                         ayush back
# 634               whoaa ayush and barkha is not back❤😔
# 635                                       im exciteddd
#
# [636 rows x 1 columns]

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import re
def remove_punc(ab):
    for cm in ab:
        if cm in string.punctuation:
            ab=ab.replace(cm,'') 
    return ab

# %%
anew['comments']=anew['comments'].apply(remove_punc)
anew
# Out:
#                                               comments
# 0    our relationship status is na tum jano na hum ...
# 1                              hrudayat vaje something
# 2    i tried finding the hoodie on meesho but i did...
# 3                                            love it ❤
# 4                          so amazing video 😍❤❤❤❤❤❤❤❤❤
# ..                                                 ...
# 631         ❤❤❤ aise he single logoki jalate rahiye 🔥🔥
# 632                                   where is apoorva
# 633                                         ayush back
# 634               whoaa ayush and barkha is not back❤😔
# 635                                       im exciteddd
#
# [636 rows x 1 columns]

# %%
anew.isnull().sum()
# Out:
# comments    0
# dtype: int64

# %%
anew.dropna(inplace=True) 
#all the Null comments are removed

# %%
ok=anew.head().iloc[0]['comments'] 
ok
# Out:
# 'our relationship status is na tum jano na hum ❤ tell us yours belowshop now on meeshotrendz trendy vibes maximize download the app now   meesho'

# %%
from textblob import TextBlob 
TextBlob(ok).sentiment.polarity
# Out:
# 0.6

# %%
def find_polarity(text):
    try:
        return TextBlob(text).sentiment.polarity 
    except:
        return 0 
anew['polarity']=anew['comments'].apply(find_polarity)
anew
# Out:
#                                               comments  polarity
# 0    our relationship status is na tum jano na hum ...  0.600000
# 1                              hrudayat vaje something  0.000000
# 2    i tried finding the hoodie on meesho but i did...  0.000000
# 3                                            love it ❤  0.500000
# 4                          so amazing video 😍❤❤❤❤❤❤❤❤❤  0.600000
# ..                                                 ...       ...
# 631         ❤❤❤ aise he single logoki jalate rahiye 🔥🔥 -0.071429
# 632                                   where is apoorva  0.000000
# 633                                         ayush back  0.000000
# 634               whoaa ayush and barkha is not back❤😔  0.000000
# 635                                       im exciteddd  0.000000
#
# [636 rows x 2 columns]

# %%
ok1=anew['polarity'].value_counts() 
ok1
# Out:
# 0.000000    307
# 0.500000     52
# 0.700000     18
# 0.600000     15
# 0.250000     15
#            ...
# 0.366667      1
# 0.175000      1
# 0.316667      1
# 0.075000      1
# 0.487500      1
# Name: polarity, Length: 100, dtype: int64

# %%
ok2=ok1.reset_index() 
ok2
# Out:
#        index  polarity
# 0   0.000000       307
# 1   0.500000        52
# 2   0.700000        18
# 3   0.600000        15
# 4   0.250000        15
# ..       ...       ...
# 95  0.366667         1
# 96  0.175000         1
# 97  0.316667         1
# 98  0.075000         1
# 99  0.487500         1
#
# [100 rows x 2 columns]

# %%
ok3=ok2.rename(columns={'index':'Polarity','polarity':'number_of_values'}) 
ok3
# Out:
#     Polarity  number_of_values
# 0   0.000000               307
# 1   0.500000                52
# 2   0.700000                18
# 3   0.600000                15
# 4   0.250000                15
# ..       ...               ...
# 95  0.366667                 1
# 96  0.175000                 1
# 97  0.316667                 1
# 98  0.075000                 1
# 99  0.487500                 1
#
# [100 rows x 2 columns]

# %%
ok3.set_index('Polarity').iloc[:20].plot(kind='bar')
#The comments with neutral polarity(0.0) are most in numbers which is followed by a lot of comments with relatively +ve polarity
#Hence as we can see , majority of comments are neutral and the rest are relatively on the positive side.
# Out:
# <AxesSubplot:xlabel='Polarity'>

# %% [markdown]
# # Emoji Analysis

# %%
import emoji 
[char for char in anew['comments'][3] if char in emoji.EMOJI_DATA]
# Out:
# ['❤']

# %%
anda11=[char for ch in anew['comments'] for char in ch if char in emoji.EMOJI_DATA] 
anda11
# Out:
# ['❤',
#  '❤',
#  '😍',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '😂',
#  '😤',
#  '😍',
#  '❤',
#  '💝',
#  '🥰',
#  '🥰',
#  '🥰',
#  '💝',
#  '☠',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '😊',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '😊',
#  '😢',
#  '❤',
#  '\U0001faf6',
#  '\U0001faf6',
#  '\U0001faf6',
#  '\U0001faf6',
#  '\U0001faf6',
#  '❤',
#  '😂',
#  '❤',
#  '❤',
#  '❤',
#  '😂',
#  '😅',
#  '❤',
#  '😊',
#  '❤',
#  '❤',
#  '😭',
#  '🥰',
#  '❤',
#  '❤',
#  '❤',
#  '😂',
#  '😅',
#  '😂',
#  '😢',
#  '😉',
#  '🤩',
#  '😭',
#  '💕',
#  '💕',
#  '😫',
#  '😫',
#  '😂',
#  '😂',
#  '😢',
#  '😭',
#  '✨',
#  '💗',
#  '😂',
#  '😂',
#  '😂',
#  '💗',
#  '😭',
#  '😭',
#  '😭',
#  '😭',
#  '❤',
#  '❤',
#  '👑',
#  '💪',
#  '😍',
#  '💞',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '❤',
#  '😭',
#  '😂',
#  '😭',
#  '💗',
#  '😍',
#  '❤',
#  '😍',
#  '😢',
#  '😍',
#  '❤',
#  '🥲',
#  '❤',
#  '🥰',
#  '🥺',
#  '💕',
#  '💘',
#  '❤',
#  '😂',
#  '😂',
#  '😂',
# ...

# %%
 from collections import Counter 
a191=Counter(anda11).most_common(10) 
a191
# Out:
# [('❤', 397),
#  ('😂', 45),
#  ('😍', 41),
#  ('🥰', 38),
#  ('😭', 28),
#  ('😊', 22),
#  ('😢', 22),
#  ('😅', 17),
#  ('🎉', 16),
#  ('✨', 12)]

# %%
import pandas as pd 
a192=pd.DataFrame({
    'emoji':[a191[i][0] for i in range(10)],
    'frequency':[a191[i][1] for i in range(10)]
}) 
a192
# Out:
#   emoji  frequency
# 0     ❤        397
# 1     😂         45
# 2     😍         41
# 3     🥰         38
# 4     😭         28
# 5     😊         22
# 6     😢         22
# 7     😅         17
# 8     🎉         16
# 9     ✨         12

# %%
a192.set_index('emoji',inplace=True) 
a192
# Out:
#        frequency
# emoji
# ❤            397
# 😂             45
# 😍             41
# 🥰             38
# 😭             28
# 😊             22
# 😢             22
# 😅             17
# 🎉             16
# ✨             12

# %%
a192.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='emoji'>
# C:\Users\LENOVO\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129392 (\N{SMILING FACE WITH SMILING EYES AND THREE HEARTS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\LENOVO\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127881 (\N{PARTY POPPER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\LENOVO\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 10024 (\N{SPARKLES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd 
anew1=pd.read_csv(r"D:\video_comments2.csv",encoding='utf-16') 
anew1
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22320\3161439740.py in <module>
#       1 import pandas as pd
# ----> 2 anew1=pd.read_csv(r"D:\video_comments2.csv",encoding='utf-16')
#       3 anew1
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
[char for char in anew1['comments'][3] if char in emoji.EMOJI_DATA]
# Out:
# []

# %%
anew22=[char for ch in anew1['comments'] for char in ch if char in emoji.EMOJI_DATA] 
anew22
# Out:
# ['©', '®', '®', '©', '©', '©', '©', '©', '©', '®', '®']

# %%
anew['comments'].apply(find_polarity)
# Out:
# 0      0.600000
# 1      0.000000
# 2      0.000000
# 3      0.500000
# 4      0.600000
#          ...
# 631   -0.071429
# 632    0.000000
# 633    0.000000
# 634    0.000000
# 635    0.000000
# Name: comments, Length: 636, dtype: float64
